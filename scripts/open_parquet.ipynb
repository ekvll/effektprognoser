# %%
import pandas as pd
import os

# %%
region = "10"
path = f"../data/parquet/{region}"
files = os.listdir(path)
for file in files:
    print(file)
# Out:
# EF_2030_RAPS_24_V1.parquet
# EF_2022_RAPS_27_V1.parquet
# EF_2040_RAPS_17_V1.parquet
# EF_2022_RAPS_23_V1.parquet
# EF_2030_PB_V1.parquet
# EF_2027_RAPS_11_V1.parquet
# EF_2040_RAPS_8_V1.parquet
# EF_2022_RAPS_14_V1.parquet
# EF_2040_RAPS_1_3_V1.parquet
# EF_2040_Smahus_V1.parquet
# EF_2022_RAPS_18_V1.parquet
# EF_2030_TT_DEP_V1.parquet
# EF_2027_RAPS_17_V1.parquet
# EF_2022_RAPS_15_V1.parquet
# EF_2027_RAPS_8_V1.parquet
# EF_2027_RAPS_18_V1.parquet
# EF_2022_RAPS_6_V1.parquet
# EF_2040_LL_V1.parquet
# EF_2030_RAPS_14_V1.parquet
# EF_2027_RAPS_14_V1.parquet
# EF_2040_LOM_Flerbostadshus_V1.parquet
# EF_2030_RAPS_19_V1.parquet
# EF_2040_TT_RESTSTOP_V1.parquet
# EF_2030_LOM_Smahus_V1.parquet
# EF_2040_RAPS_6_V1.parquet
# EF_2030_RAPS_9_V1.parquet
# EF_2040_RAPS_18_V1.parquet
# EF_2022_Flerbostadshus_V1.parquet
# EF_2040_RAPS_21_V1.parquet
# EF_2030_RAPS_5_V1.parquet
# EF_2030_RAPS_23_V1.parquet
# EF_2027_RAPS_8888_V1.parquet
# EF_2027_RAPS_21_V1.parquet
# EF_2040_LOM_Smahus_V1.parquet
# ...

# %%
df = pd.read_parquet(f"{path}/{files[0]}")
df
# Out:
#               rid                                                 lp  \
# 0   4810006229000  [9.858425770583163e-05, 9.8283065930843e-05, 9...
# 1   4840006229000  [9.858425770583163e-05, 9.8283065930843e-05, 9...
# 2   4860006234000  [9.858425770583163e-05, 9.8283065930843e-05, 9...
# 3   4890006228000  [9.858425770583163e-05, 9.8283065930843e-05, 9...
# 4   4890006229000  [9.858425770583163e-05, 9.8283065930843e-05, 9...
# 5   4890006230000  [9.858425770583163e-05, 9.8283065930843e-05, 9...
# 6   4900006226000  [9.858425770583163e-05, 9.8283065930843e-05, 9...
# 7   4910006225000  [0.00029575277311749487, 0.000294849197792529,...
# 8   4920006223000  [0.0009858425770583163, 0.00098283065930843, 0...
# 9   4920006224000  [0.0026617749580574537, 0.002653642780132761, ...
# 10  4950006227000  [0.0006900898039408214, 0.0006879814615159011,...
# 11  4960006232000  [0.00029575277311749487, 0.000294849197792529,...
# 12  4970006231000  [9.858425770583163e-05, 9.8283065930843e-05, 9...
# ...
